# %% [markdown]
# <h3>QUANTUM COMPUTING</h3>

# %% [markdown]
# <h4> A self study material prepared by Issa Adesina Fatai </h4>
# <h5> A Postgraduate Research Student, University of Ilorin, Dept of Computer Science </h5>

# %% [markdown]
# <h4>Quantum Computing</h4>

# %% [markdown]
# A <b>qubit</b> (quantum bit) is the fundamental unit of quantum information, analogous to a classical bit in digital computing.

# %% [markdown]
# A classical bit is binary: it can be either 0 or 1. <br> In a classical circuit, the state of the system is the value of each bit at any point in time. If you have 2 bits, they can be in one of 4 possible states: 00, 01, 10, or 11. This is called the binary state. It means no of state= 2^(no-of-bit). For 3bits, the possible states are 000,001,010,100,110,111 ,011,101 that is 8 possible states. So in classical system. But classical system can ONLY be in ONE of these possible states.

# %% [markdown]
# As for Qubit, if a Quantum system has 2qubits, the Quantum states are expressed in vector form called Statevector. It is not just about the state but it combines the probability of existence of the state. So Quantum system with 2 qubits has states as 00,10,01,11 in superposition. That is all the states exist simultaneously, though each existing state has its probability amplitude of the existence.

# %% [markdown]
# <h4>Dirac Notation (Bra and Ket Notation)</h4>  Dirac notation (also called bra-ket notation) is a standard mathematical notation widely used in quantum mechanics to describe quantum states. It is a concise way to represent vectors (states) and linear functionals (dual vectors) in Hilbert space, which is the mathematical space where quantum states reside.

# %% [markdown]
# In Dirac notation:
#
# A ket :
# ∣ψ⟩ represents a quantum state (a vector in Hilbert space).
# A bra :
# ⟨ψ∣ represents the conjugate transpose (dual vector) of the corresponding ket.
# The combination of a bra and a ket,
# ⟨
# 𝜓
# ∣
# 𝜙
# ⟩
# ⟨ψ∣ϕ⟩, represents an inner product (a complex number) between the states
# ∣
# 𝜓
# ⟩
# ∣ψ⟩ and
# ∣
# 𝜙
# ⟩
# ∣ϕ⟩.

# %% [markdown]
# ∣ψ⟩ is used to represent Quantum state in Quantum Mechanics. And it can be written as a linear combination (or superposition) of basis states ∣0⟩ and ∣1⟩ as: ∣ψ⟩=α∣0⟩+β∣1⟩. <br> where α and β are complex numbers (called probability amplitudes) and satisfy the normalization condition:
# ∣α∣^2 +∣β∣^2 =1
# This means that the total probability of measuring either ∣0⟩  or ∣1⟩ is 1.

# %% [markdown]
# If a quantum system has 3 qubits, the number of possible states that the system can be in is 2^3 =8.
# Each qubit from the three can exist in two possible states, either ∣0⟩ or ∣1⟩. <br>
# That is :<br>
# <b>Qubit1(ψ1⟩)</b> can exist in either ∣0⟩ or ∣1⟩. We write it as ∣ψ1⟩=α1∣0⟩+β1∣1⟩ <br>
# <b>Qubit2(ψ2⟩)</b> can exist in either ∣0⟩ or ∣1⟩. We write it as ∣ψ2⟩=α2∣0⟩+β2∣1⟩ <br>
# <b>Qubit1(ψ3⟩)</b> can exist in either ∣0⟩ or ∣1⟩. We write it as ∣ψ3⟩=α3∣0⟩+β3∣1⟩ <br>
#
#
# ![Screenshot from 2024-10-18 15-16-31.png](attachment:dc0a4c83-1928-438c-bc5b-2ec546d74ab9.png)
#
# <h5>Expanding this product yields 8 terms, corresponding to the 8 possible states of the 3-qubit system:</h5>
#
# ![Screenshot from 2024-10-18 15-18-07.png](attachment:3b10e75d-6928-49a5-836f-30098389f217.png)
#
#
#
# For 3 qubits, each possible state can be represented as a tensor product (combination) of the individual qubit states.
#
#
# 1)  ∣000⟩ — All qubits in state ∣0⟩
# 2)  ∣001⟩ — First two qubits in ∣0⟩,third qubit in ∣1⟩
# 3)  ∣010⟩ — First qubit in ∣0⟩,second qubit in ∣1⟩,third qubit in ∣0⟩
# 4)  ∣011⟩ — First qubit in ∣0⟩, second qubit in ∣1⟩ and third in ∣1⟩
# 5)  ∣100⟩ — First qubit in ∣1⟩, second and third qubits in ∣0⟩
# 6)  ∣101⟩ — First and third qubits in ∣1⟩,second qubit in ∣0⟩
# 7)  ∣110⟩ — First and second qubits in ∣1⟩, third qubit in ∣0⟩
# 8)  ∣111⟩ — All qubits in state ∣1⟩
#
# Do not forget that our case study here uses 3 qubits. And the general state formular is :  ∣ψ⟩ = α∣0⟩ + β∣1⟩ where
#  𝛼 and β are probability amplitudes for existence of each state for a qubit.
# In the no (1) above, all the 3 qubits in state ∣0⟩.
# So how do we write the  state for the three qubits in no (1) where all are in ∣0⟩ ?
# For the first qubit , remember that ∣ψ⟩ = α∣0⟩ + β∣1⟩ a single qubit. α∣0⟩ is a state and β∣1⟩ is its conjugate. In superposition the two states exist based on the probability amplitude of each. They could be 0.5 and 0.5 , 1 and 0, 0.75 and 0.25 etc .
# In our case in no (1) above, ∣000⟩ — All qubits in state ∣0⟩, so the state expression will be written as <br>
#
# ∣ψ⟩ = 1∣0⟩ + 0∣1⟩  that is α=1, which means ∣0⟩ exists, and β=0 which means ∣1⟩  do not exits.
# Since the three qubits in state ∣0⟩, then we have for the three of them:
# ![Screenshot from 2024-10-18 15-16-31.png](attachment:dc0a4c83-1928-438c-bc5b-2ec546d74ab9.png)
#
#
# i.e The full state of the 3-qubit system is the tensor product of these individual qubit states.
# For 3 qubits, each possible state can be represented as a tensor product (combination) of the individual qubit states.

# %% [markdown]
# <h4> So for all the possible 8 states we have:</h4>
#
# ![Screenshot from 2024-10-18 15-42-12.png](attachment:171a5331-63b4-411d-ba50-c2038dc9d0f2.png)

# %% [markdown]
# <h4> PRACTICAL DEMOSTRATION </h4>
#
# To practicalize these ideas , we need a Quantum Computer, but I know that is hard to comeby by now. But we shall use Frameworks from IBM or Google.

# %% [markdown]
# <b>Qiskit</b> is an open-source quantum computing framework from IBM for working with quantum circuits, and it provides tools for simulating and executing quantum algorithms on both simulators and real quantum computers. <h5>Google Cirq</h5> It is another open source for the same advantage. However, we shall use IBM's Qiskit first to illustrate all we had explained above

# %% [markdown]
# To use Qiskit, we need to install it.  Having latest python installed on our machine, we need to create a virtual enviroment for our Quantum project

# %% [markdown]
# On Linux ,
# #python3 -m venv /path/to/virtual/environment
#
# Next, activate your new environment.
# #source /path/to/virtual/environment/bin/activate
#
# To install the Qiskit SDK. If you plan to run jobs on quantum hardware, also install Qiskit Runtime.
# We ned to install pip if not installed before
# After that we install Qiskit
# #pip install qiskit
# Then:
# #pip install qiskit-ibm-runtime
#
# Then:
# #pip install qiskit[visualization]   # for visualization if jupyter is in use
#
# Then : Install Jupyter
# #pip install jupyter
#
# launch Jupyter
# Then open your notebook as follows:
# #jupyter notebook
#
# For more information about installation, visit: https://docs.quantum.ibm.com/guides/install-qiskit

# %% [markdown]
# <h4>Quantum Circuit</h4>
#
# <b>Quantum Circuit is like Digital Circuit in Classical System. We know that a Digital circuit comprises of logic gates (AND-gate,NOT-gate etc) arranged in a way to perform operation on the inputs which are in bits.
# So is the Quantum Circuit.A quantum circuit is a sequence of quantum gates to operates on qubits by manipulating their states using quantum gates </b>
# <br>
# Quantum circuits are built on qubits, which can be in a superposition of 0 and 1 states.
# Quantum gates are similar to classical logic gates. These are the common quantum gates:
# <p>X (Pauli-X): flips a qubit's state:  If the input qubit is |0⟩ (represented as [1, 0] in vector form), the X gate turns it into |1⟩ </p>
# <p>H (Hadamard): creates superposition.Makes the quantum system to have all the possible states in existence with their probability</p>
# <p>CX (CNOT): entangles qubits.That it connect states together regardless of their separation or distance apart</p>

# %% [markdown]
# <h4>Let Us Create a design a Quantum Circuit from a single qubit</h4>

# %%
#import QuantumCircuit class from Qiskit
from qiskit import QuantumCircuit


# Create a Quantum Circuit with 1 qubits
qc = QuantumCircuit(1)

# Draw the circuit
qc.draw('mpl')

# %% [markdown]
# <h4> As you can see, the Circuit has no gate, so there can not be possible operation on the qubits</h4>
# Let us repeat the process but with a gate (Hadamard gate)

# %%
#import QuantumCircuit class from Qiskit
from qiskit import QuantumCircuit


# Create a Quantum Circuit with 1 qubit
qc = QuantumCircuit(1)

# With Hadamard gate to make the qubit be in superposition
qc.h(0)
# Draw the circuit
qc.draw('mpl')

# %%
#import QuantumCircuit class from Qiskit
from qiskit import QuantumCircuit


# Create a Quantum Circuit with 2 qubits
qc = QuantumCircuit(2)


# With Hadamard gate to make the first qubit be in superposition
qc.h(0)

# With Hadamard gate to make the second qubit be in superposition
qc.h(1)

# Draw the circuit
qc.draw('mpl')

# %%
<h4> Let us CX (CNOT) gate:to entangles qubits.</h4>

# %%
#import QuantumCircuit class from Qiskit
from qiskit import QuantumCircuit


# Create a Quantum Circuit with 2 qubits
qc = QuantumCircuit(2)


# With Hadamard gate to make the first qubit be in superposition
qc.h(0)

# With Hadamard gate to make the second qubit be in superposition
qc.h(1)

qc.cx(0, 1)  # Entangle qubit 0 and qubit 1

# Draw the circuit
qc.draw('mpl')
